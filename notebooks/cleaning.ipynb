# %% [markdown]
# # Cleaning the Data
#
# It's always important to preview your data and clean it up before training.

# %%
import pandas as pd

# %%
dataset = pd.read_csv("../data/datasetv1.csv")

# %%
dataset
# Out:
#        Unnamed: 0    appid                        name release_date  english  \
# 0               0       10              Counter-Strike   2000-11-01        1
# 1               1       20       Team Fortress Classic   1999-04-01        1
# 2               2       30               Day of Defeat   2003-05-01        1
# 3               3       40          Deathmatch Classic   2001-06-01        1
# 4               4       50   Half-Life: Opposing Force   1999-11-01        1
# ...           ...      ...                         ...          ...      ...
# 27070       27070  1065230             Room of Pandora   2019-04-24        1
# 27071       27071  1065570                   Cyber Gun   2019-04-23        1
# 27072       27072  1065650            Super Star Blast   2019-04-24        1
# 27073       27073  1066700  New Yankee 7: Deer Hunters   2019-04-17        1
# 27074       27074  1069460                   Rune Lord   2019-04-24        1
#
# ...
